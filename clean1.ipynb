# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('crude_death_rate.csv', skiprows=2)
df = df.drop(['Country Code', 'Indicator Code', 'Indicator Name', '2020','Unnamed: 65'], 1)
df = df.replace(r'^\s*$', np.nan, regex=True)
df = df.style.set_caption("Death rate, crude (per 1,000 people)")
df
# Out:
# /Users/aurorali/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <style type="text/css">
# </style>
# <table id="T_18f8d_">
#   <caption>Death rate, crude (per 1,000 people)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Country Name</th>
#       <th class="col_heading level0 col1" >1960</th>
#       <th class="col_heading level0 col2" >1961</th>
#       <th class="col_heading level0 col3" >1962</th>
#       <th class="col_heading level0 col4" >1963</th>
#       <th class="col_heading level0 col5" >1964</th>
#       <th class="col_heading level0 col6" >1965</th>
#       <th class="col_heading level0 col7" >1966</th>
#       <th class="col_heading level0 col8" >1967</th>
#       <th class="col_heading level0 col9" >1968</th>
# ...
